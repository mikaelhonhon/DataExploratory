# %% [markdown]
# <a href="https://colab.research.google.com/github/mikaelhonhon/DataExploratory/blob/main/Data_explore.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c9f86ff7-e948-49ae-9b8e-72137923a93a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c9f86ff7-e948-49ae-9b8e-72137923a93a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Testing.csv to Testing.csv

# %%
df = pd.read_csv('Testing.csv', index_col = False)

# %%
df
# Out:
#       year  state name  chrstprot  ...  recreliab  reliabilevel  Version  sourcecode
# 0     1945      2  USA   66069671  ...         10        Medium      1.1          13
# 1     1950      2  USA   73090083  ...         28           Low      1.1          18
# 2     1955      2  USA   79294628  ...         10        Medium      1.1          15
# 3     1960      2  USA   90692928  ...         10        Medium      1.1          13
# 4     1965      2  USA   94165803  ...         28           Low      1.1          20
# ...    ...    ...  ...        ...  ...        ...           ...      ...         ...
# 1990  1990    990  WSM      98400  ...         10        Medium      1.1           7
# 1991  1995    990  WSM      99000  ...         20        Medium      1.1           1
# 1992  2000    990  WSM     138600  ...         10        Medium      1.1          83
# 1993  2005    990  WSM     140910  ...         10        Medium      1.1          83
# ...

# %%
df['chrstprot'].mean()
# Out:
# 120748.0

# %%
df['chrstprot'].median()
# Out:
# 120748.0

# %%
df['chrstprot'].max()
# Out:
# 132040181

# %%
df['chrstprot'].min()
# Out:
# 0

# %%
df.hist(column='chrstprot',by = 'year')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f4747b94a90>,
# ...
#       dtype=object)
